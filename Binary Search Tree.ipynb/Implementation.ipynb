# %% [markdown]
# **What is BST?**
#
# where is value of
#
# Left<Root<Right
#
# **What if two Values got same?**
#
# then
#
# Left<=Root<Right

# %% [markdown]
# **Why BST over BT?**
#
# *BT can give us complexity of O(n) in worst case like to traverse all the nodes but in case of BST we will only get complexity of O(logn) in worst case which is much far better than it*
