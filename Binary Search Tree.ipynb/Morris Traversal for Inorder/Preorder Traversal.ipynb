# %% [markdown]
# **Morris Traversal is also a traversal technique like we have learnt in pre,in,popstorder traversal but these three techniques gives us the TC of O(n) and SC of O(n) whereas morris traversal will do this same work in a optimized manner which will give us TC of O(n) and SC of O(1) now the space complexity become constant where as in normal traversal we got SC pf O(n) whcih is due to Stack space occupied due to DFS**
