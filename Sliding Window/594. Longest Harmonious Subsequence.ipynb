# %%
def solve(nums):
    left=0
    right=0
    my_dict={}
    while left<len(nums):
        if nums[left] not in my_dict:
            my_dict[nums[left]]=1
        else:
            my_dict[nums[left]]+=1
