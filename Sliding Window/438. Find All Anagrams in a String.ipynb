# %% [markdown]
# # My approach

# %%
class Solution(object):
    def findAnagrams(self, s, p):
        """
        :type s: str
        :type p: str
        :rtype: List[int]
        """
        hash_map1={}
        for i in p:
            if i not in hash_map1:
                hash_map1[i]=1
            else:
                hash_map1[i]+=1
        hash_map2={}
        list1=[]
        left=0
        right=0
        while right<=len(s):
            if hash_map1==hash_map2:
                list1.append(left)
                print(hash_map2)
                hash_map2.pop(s[left])
                left+=1
            if right<len(s):
                if s[right] in hash_map1 and s[right] not in hash_map2:
                    if len(hash_map2)==0:
                        left=right
                    hash_map2[s[right]]=1
                elif s[right] in hash_map1 and s[right] in hash_map2:
                    if hash_map2[s[right]]<hash_map1[s[right]]:
                        hash_map2[s[right]]+=1
                    else:
                        if hash_map1==hash_map2:
                            list1.append(left)
                            hash_map2.pop(s[left])
                            left+=1
                        else:
                            hash_map2={}
                            right=left+1
                            continue
                            
                elif s[right] not in hash_map1:
                
                    hash_map2={}
            right+=1
        return list1
