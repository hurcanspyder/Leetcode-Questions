# %%
class Solution(object):
    def haveConflict(self, event1, event2):
        """
        :type event1: List[str]
        :type event2: List[str]
        :rtype: bool
        """
        list1 = [
            [
                float(event1[0][0:2]) + float(event1[0][3:5]) / 100,
                float(event1[1][0:2]) + float(event1[1][3:5]) / 100
            ],
            [
                float(event2[0][0:2]) + float(event2[0][3:5]) / 100,
                float(event2[1][0:2]) + float(event2[1][3:5]) / 100
            ]
        ]
        list1.sort()
        print(list1)
        return list1[1][0]<=list1[0][1]
