# %%
class Solution(object):
    def longestPalindrome(self, s):
        """
        :type s: str
        :rtype: str
        """
        i=0
        j=1
        max1=0
        list1=[]
        a=""
        for i in range(0,len(s)):
            for j in range(i,len(s)):
                if s[i:j+1] == s[i:j+1][::-1]:
                    if (j+1)-i>max1:
                        a=s[i:j+1]
                        max1=(j+1)-i



                    
                    
        return a

# %% [markdown]
# # Must read this please its imp written behind the main logic of using longest common subseq

# %% [markdown]
# *It can be done by (longest common subsequence) if we change the direction of text and mark it as a second text to check for the longest common subseq its mere gennuine*

# %% [markdown]
# # I have to fix this code !!!!!

# %%
class Solution(object):
    def longestPalindrome(self, s):
        """
        :type s: str
        :rtype: str
        """
        a=s[::-1]
        def func(a,s):
            n=len(a)
            m=len(s)
            dp=[[0 for _ in range(m+1)]for _ in range(n+1)]

            for i in range(1,m+1):
                for j in range(1,n+1):
                    if s[i-1]==a[j-1]:
                        dp[i][j]=1+dp[i-1][j-1]
                    else:
                        dp[i][j]=0
            
            return dp
        dp= func(a,s)
        max1=0
        index1=0
        index2=0
        for i in range(len(dp)):
            for j in range(len(dp[0])):
                if dp[i][j]>max1:
                    index1=i
                    index2=j
                    max1=dp[i][j]
        h=""
        while dp[index1][index2]!=0:
            h=h+s[index1-1]
            index1-=1
            index2-=1
        return h

# %% [markdown]
# # Chat gpt code

# %%
class Solution(object):
    def longestPalindrome(self, s):

        a = s[::-1]
        n = len(s)

        dp = [[0]*(n+1) for _ in range(n+1)]
        max_len = 0
        end_index_s = 0

        for i in range(1, n+1):
            for j in range(1, n+1):
                if s[i-1] == a[j-1]:
                    dp[i][j] = 1 + dp[i-1][j-1]

                    length = dp[i][j]
                    start_s = i - length
                    start_rev = j - length

                    # check palindrome mirror condition
                    if start_s == (n - 1 - (j-1)):
                        if length > max_len:
                            max_len = length
                            end_index_s = i

        return s[end_index_s - max_len : end_index_s]
