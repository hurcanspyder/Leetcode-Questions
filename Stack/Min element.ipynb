# %%
class MinStack(object):

    def __init__(self):
        self.items=[]
        self.min_element=10**10
        

    def push(self, val):
        """
        :type val: int
        :rtype: None
        """
        # if val<self.min_element:
        #     self.min_element=val
        # self.items.append([val,self.min_element])
        if len(self.items)==0:
            self.items.append([val,val])
        else:
            min_element=min(self.items[-1][1],val)
            self.items.append(val,min_element)

        

    def pop(self):
        """
        :rtype: None
        """
        if len(self.items)==0:
            return 0
        e=self.items.pop()
        # return e
        if self.min_element==e:
            self.min
        
        

    def top(self):
        """
        :rtype: int
        """
        if len(self.items)==0:
            return 0
        return self.items[-1]
        

    def getMin(self):
        """
        :rtype: int
        """
        if len(self.items)==0:
            return 0
        return self.items[-1][1]

# %%
obj=MinStack()

# %%
obj.push(10)
obj.push(20)
obj.push(30)
obj.push(2)

# %%
obj.getMin()
# Out:
# 2

# %%
obj.pop()

# %%
obj.getMin()
# Out:
# 10
