# %% [markdown]
# # Double Ended Queue

# %%
from collections  import deque

# %%
list=deque([])

# %%
list.append(100)
list.append(200)
list.append(300)
list.appendleft(1)

# %%
list
# Out:
# deque([1, 100, 100, 200, 300])
