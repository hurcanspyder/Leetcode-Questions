# %% [markdown]
# **Branch and Bound is an optimization technique that systematically explores the solution space by branching into subproblems and using bounds to eliminate suboptimal solutions. It reduces computation by pruning nodes that cannot lead to an optimal solution.**
