# %% [markdown]
# # Mine one Not optimal

# %%
class Solution(object):
    def nthUglyNumber(self, n):
        """
        :type n: int
        :rtype: int
        """
        # ugly=[2,3,5]
        my_set=set()
        # def check(num,j):
        #     if num==1:
        #         return True
        #     if j>2:
        #         return False
        #     if num%ugly[j]==0:
        #         num=num//ugly[j]
        #     elif num%ugly[j]!=0 and i!=2:
        #         j+=1
        #     elif num%ugly[j]!=0 and i==2:
        #         return False
        #     return check(num,j)
            
            
            

           
        k=1 
        my_set.add(1)
        for i in range(1,2*10**7):
            a,b,c=0,0,0
            if i%2==0:
                a=i//2
            if i%3==0:
                b=i//3
            if i%5==0:
                c=i//5
            if a in my_set or b in my_set or c in my_set:
                my_set.add(i)
                print(i)
                k+=1

            
            if k==n:
                return i
