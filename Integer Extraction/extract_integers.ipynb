# %%
def extract_integers(nums):
    
    while(nums>0):
        last_digit=nums%10
        print(last_digit)
        nums=nums//10
nums=int(input())
extract_integers(nums)

# %%
# Out:
# 3
# 7
# 8
# 5
