# %% [markdown]
# # Minimum Spanning Tree
#
# *A tree with N nodes and N-1 edges and all the nodes should be reachable but with the smallest overall weight(sum all the weights)*

# %% [markdown]
# What we have to do is make a spanning tree and identify how many different types of spanning tree can be formed through a partucular graph
