# %% [markdown]
# # Below is mine one but it is little bit inefficient

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution(object):
    def findTarget(self, root, k):
        """
        :type root: Optional[TreeNode]
        :type k: int
        :rtype: bool
        """
        def func(root,result):
            if not root:
                return 
            func(root.left,result)
            result.append(root.val)
            func(root.right,result)
            return result
        a=func(root,[])
        b=set(a)
        for i in range(0,len(a)):
            if k-a[i] in b and k-a[i]!=a[i]:
                return True
        return False

# %% [markdown]
# # Optimal one

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution(object):
    def findTarget(self, root, k):
        seen=set()
        def dfs(node):
            if not node:
                return False
            complement=k-node.val    
            if complement in seen:
                return True
            seen.add(node.val)
            return dfs(node.left) or dfs(node.right)
        return dfs(root)
