# %%
class Solution(object):
    def maximumHappinessSum(self, happiness, k):
        """
        :type happiness: List[int]
        :type k: int
        :rtype: int
        """
        happiness.sort()
        count=0
        n=len(happiness)-1
        while count!=k:
            for i in range(0,n-count):
                if happiness[i]>0:
                    happiness[i]-=1
            count+=1
        return sum(happiness[len(happiness)-k:len(happiness)])

# %%
class Solution(object):
    def maximumHappinessSum(self, happiness, k):
        """
        :type happiness: List[int]
        :type k: int
        :rtype: int
        """
        happiness.sort()
        count=0
        n=len(happiness)-1
        while count!=k:
            for i in range(0,n-count):
                if happiness[i]>0:
                    happiness[i]-=1
            if sum(happiness[0:n-count])==0:
                return sum(happiness[len(happiness)-k:len(happiness)])

            count+=1
        return sum(happiness[len(happiness)-k:len(happiness)])

# %% [markdown]
# # Above code show TLE error

# %%
class Solution(object):
    def maximumHappinessSum(self, happiness, k):
        """
        :type happiness: List[int]
        :type k: int
        :rtype: int
        """
        happiness.sort()
        count=0
        n=len(happiness)-1
        for i in range(n,-1,-1):
            if happiness[i]-count>=0:
                happiness[i]-=count
                count+=1
            
                
            else:
                happiness[i]=0
                count+=1
                
            
        return sum(happiness[len(happiness)-k:len(happiness)])
