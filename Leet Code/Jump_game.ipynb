# %%
def canJump(nums):
    position=0
    for i in range(0,len(nums)-1):
        pass

# %%
def canJump(nums):
    position=0

    p=1
    print(p)
    def jmp ():
        global p
        p=5
        print(p)
    
    jmp()
    print(p)

canJump([2,3,1,1,4])
# Out:
# 1
# 5
# 1

# %%
list1=[3,2,1,0,4]
position=0
max_jump=list1[position]
destination=len(list1)-1
def func(list1,m):
    global position
    global max_jump
    if position+list1[position]==destination:
        print("Hello")
        return True
    elif list1[position+list1[position]]==0:
        print("idhr")
        max_jump-=1 
        if max_jump>0:
            func(list1,max_jump)
        if max_jump==0:
            position-=1
    else:
        position=position+max_jump
        max_jump=list1[max_jump]
        print("AAAAAA")
        func(list1,max_jump)
    
func(list1,list1[0])
# Out:
# idhr
# idhr
# idhr

# %%
list1=[3,2,1,1,4]
position=0
max_jump=list1[position]
destination=len(list1)-1
c=0
def func(list1,m):
    global position
    global max_jump
    global c

    if position+list1[position]==destination:
       return True
    elif list1[position+list1[position]]==0:
        print("idhr")
        max_jump-=1 
        if max_jump>0:
            func(list1,max_jump)
        if max_jump==0:
            position-=1
    else:
        position=position+list1[position]
        # max_jump=list1[position]
       
        func(list1,list1[position])

    
print(func(list1,list1[0]))
# Out:
# None

# %%
list1 = [1,0,1,1]
position = 0
max_jump = list1[position]
destination = len(list1) - 1
c = 0

def func(list1, m):
    global position
    global max_jump
    global c

    if position + list1[position] == destination:
        return True
    elif position + list1[position] >= len(list1):
        return True
    elif list1[position + list1[position]] == 0:
        max_jump -= 1
        if max_jump > 0:
            position+=1
            return func(list1, max_jump)
        if max_jump == 0:
            position -= 2
            return func(list1,list1[position])
    else:
        position = position + list1[position]
        max_jump=list1[position]
        return func(list1, list1[position])
    
    return False 

print(func(list1, list1[0]))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
