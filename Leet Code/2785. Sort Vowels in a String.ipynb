# %%
print(ord('u'))
# Out:
# 117

# %%
map={'A','E','I','O','U','a','e','i','o','u'}

# %%
if 'i' in map:
    print("h")
# Out:
# h

# %%
def solve(s):
    map={'A','E','I','O','U','a','e','i','o','u'}
    a=[]
    from collections import deque
    queue=[]
    for i in range(len(s)):
        a.append(s[i])
        if s[i] in map:

            
            if len(queue)==0:
                queue.append(s[i])
                
            else:
                flag=True
                for j in range(len(queue)):
                    
                    if ord(s[i])<ord(queue[j]):
                        queue.insert(j,s[i])
                        flag=False
                        break
                    
                        
                if flag==True:
                    queue.append(s[i])
    count=0
    print(queue)
    for i in range(len(s)):
        if a[i] in map:
            a[i]=queue[count]
            count+=1
                    
                    

    return "".join(a)

# %%
solve("absihehkaAnljbdbs")
# Out:
# ['A', 'a', 'a', 'e', 'i']
# 'Absahahkeinljbdbs'

# %%
a=[1,2,3]
a.insert(1,44)

# %%
a
# Out:
# [1, 44, 2, 3]
