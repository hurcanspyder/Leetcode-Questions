# %%
class Solution(object):
    def totalMoney(self, n):
        """
        :type n: int
        :rtype: int
        """
        sum=0
        if n<=7:
            for i in range(0,n+1):
                sum=sum+i
            return sum
        else:
            count=1
            count1=1
            monday_dep=1
            while count<=8 and count1<=n:
                if count>7:
                    monday_dep+=1
                    count=monday_dep
                print(sum)
                sum=sum+count
                count+=1
                count1+=1
            return sum
