# %%
def getNoZeroIntegers(n):
    """
    :type n: int
    :rtype: List[int]
    """
    for i in range(1,n):
        a=n-i
        list1=[]
        list2=[]
        b=i       
        while a>0:
            
            list1.append(a%10)
            a=a//10
        while b>0:
            list2.append(b%10)
            b=b//10
        flag1=True
        for k in list2:
            if k==0:
                flag1=False
                break
        
       
            

        flag=True
        for j in list1:
            if j==0:
                flag=False
                break
        if flag and flag1:
            return [i,n-i]

# %%
getNoZeroIntegers(4102)
# Out:
# [111, 3991]
