# %%
def game(cards):
    set1=set((24,2,12,3,8,4,6))
    sum=0
    for i in cards:
        sum=sum+i
    if sum==24: return True
    for i in range()

# %%
a=set((2,3,4,5))

# %%
type(a)
# Out:
# set
