# %%
class Solution(object):
    def intersection(self, nums1, nums2):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :rtype: List[int]
        """
        return list(set(nums1) & set(nums2))

# %%
a=[1,2,3,2,3,3,3,3,3]adknallamdlllalm;ldmmax:LAmxm
a[0:3]
# Out:
# [1, 2, 3]
