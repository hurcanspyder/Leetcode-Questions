# %%
def yet_another_two_integer_problem(number,list1):
    i=0
    while(number>0):
        
        a=list1[i][0]
        b=list1[i][1]
        if b>a:
            if (b-a)>=10:
                if((b-a)%10)!=0:
                    print((b-a)//10+1)
                    i+=1
                    number-=1
                else:
                    print((b-a)//10)
                    i+=1
                    number-=1
            else:
                print(1)
                i+=1
                number-=1
        elif(a==b):
            print(0)
            i+=1
            number-=1

        else:
            if (a-b)>=10:
                if ((a-b)%10)!=0:
                    print((a-b)//10+1)
                    i+=1
                    number-=1
                else:
                    print((a-b)//10)
                    i+=1
                    number-=1
            else:
                print(1)
                i+=1
                number-=1


list1=[]
number=int(input())
for i in range(0,number):
    list2 = list(map(int, input().split()))
    list1.append(list2)


yet_another_two_integer_problem(number,list1)
# Out:
# [[5, 5], [13, 42], [18, 4], [1337, 420], [123456789, 1000000000], [100500, 9000]]
# 0
# 3
# 2
# 92
# 87654322
# 9150

# %%
a=[[5, 5], [13, 42]]

# %%
(100500-9000)%10
# Out:
# 0
