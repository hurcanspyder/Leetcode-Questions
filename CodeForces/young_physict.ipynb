# %%
def young_physict(list1):
    list2=[]
    for i in range(0,len(list1[0])):
        a=0
        for j in range (0,len(list1)):
            a=a+list1[j][i]
        if a==0:
            list2.append("YES")
        
        else:
            list2.append("NO")
    if "NO" in list2:
        print("NO")
    else:
        print("YES")



number=int(input())


list2=[]
while(number>0):
    list1=[]
    # for i in range(0,3):
        
    #     cord=int(input())
        # list2.append(cord)
    list1 = list(map(int, input().split()))
    list2.append(list1)
    

    
    number-=1
    
young_physict(list2)
# Out:
# NO

# %%
list2=[[]]
list2[0].append(1)
list2[1].append(23)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 list2=[[]]
#       2 list2[0].append(1)
# ----> 3 list2[1].append(2)
#
# IndexError: list index out of range

# %%
a=[1,2,3]
b=[4,5,6]

# %%
c=[]
c.append(a)
c.append(b)

# %%
len(c)
# Out:
# 2

# %%
list1 = list(map(int, input().split()))
# Out:
# tuple
