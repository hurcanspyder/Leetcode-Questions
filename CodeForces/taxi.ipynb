# %%
def taxi(number,list1):
    sum=0
    for i in range(0,number):
        sum=sum+list1[i]
    if sum%4==0:
        print(int(sum/4))
    else:
        print(int(sum/4)+1)



    


    


number=int(input())
list1 = list(map(int, input().split()))
taxi(number,list1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 18
#       7     else:
#       8         print(int(sum/4)+1)
# ---> 18 number=int(input())
#      19 list1 = list(map(int, input().split()))
#      20 taxi(number,list1)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def taxi(number,list1):
    count=0
    dict1={'4':0,'3':0,'2':0,'1':0}
    list3=[]
    list1=sorted(list1,reverse=True)
    for i in range(0,number):
        if list1[i]==4:
            dict1['4']+=1
        elif(list1[i]==3):
            dict1['3']+=1
        elif(list1[i]==2):
            dict1['2']+=1
        elif(list1[i]==1):
            dict1['1']+=1
    print(dict1)
    if (dict1['3']>dict1['1']):
        total=dict1['4']+dict1['3']-dict1['1']+dict1['1']+(dict1['2']/2)
        print(total)
    else:
        total=dict1['4']+dict1['1']-dict1['3']+dict1['1']+int(dict1['2']/2)
        print(total)
        




    


    


number=int(input())
list1 = list(map(int, input().split()))
taxi(number,list1)
# Out:
# {'4': 0, '3': 2, '2': 1, '1': 0}
# 2.5

# %%
a=[2,3,4,4,2,1,3,1]
a=sorted(a)
a
# Out:
# [1, 1, 2, 2, 3, 3, 4, 4]

# %%
len(a)
# Out:
# 8

# %%
dict1={'4':0,'3':0,'2':0,'1':0}
print(dict1['3'])
# Out:
# 0

# %%
dict1['4']=1

# %%
dict1.values()
# Out:
# 1
# 0
# 0
# 0

# %%
dict1=[2:1,3:1,4:1]
