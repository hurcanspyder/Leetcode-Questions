# %%
def chatroom(string1):
    word='hello'
    list1=[]
    # for j in range(0,len(word)):
    a=0
    for i in range(0,len(string1)):
        if string1[i]==word[a]:
            # if string1[i] not in list1:
            list1.append(string1[i])
            a=a+1
            
            # print(a)
            # print("YES")
            # print(list1)
        if list1==['h','e','l','l','o']:
            print("YES")
            break
        else:
            # print('no')
            continue
    if list1!=['h','e','l','l','o']:
        print("NO")

string1=str(input())
chatroom(string1)
# Out:
# NO

# %%
chatroom('ahhellllloou')
# Out:
# YES
