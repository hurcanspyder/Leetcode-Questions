# %%
def interesting_drink(number,list1,no_of_days,list2):

    for i in range(0,len(list2)):
        count=0
        for j in range(0,len(list1)):
            if list1[j]<=list2[i]:
                count=count+1
        print(count)



number=int(input())
list1 = list(map(int, input().split()))
no_of_days=int(input())
list2=[]
for i in range(0,no_of_days):
    a=int(input())
    list2.append(a)
interesting_drink(number,list1,no_of_days,list2)
# Out:
# 0
# 4
# 1
# 5

# %%
a = int(input)
