# %%
def raising_bacteria(number1):
    import math
    if math.log2(number1).is_integer():
        print(1)
    else:
        a=int(math.log2(number1))
        print(number1-2**a+1)

        
number1=int(input())
raising_bacteria(number1)
# Out:
# 268435456

# %%
import math
number=536870911
int(math.log2(number))
# Out:
# 28

# %%
536870911-2**28
# Out:
# 268435455

# %%
print(536870911-2**28)
# Out:
# 268435455

# %%
(2**28)*2
# Out:
# 536870912
