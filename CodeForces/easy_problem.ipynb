# %%
def easy_problem(number,list1):
    if 1 in list1:
        print("HARD")
    else:
        print("EASY")

number=int(input())
list1 = list(map(int, input().split()))
easy_problem(number,list1)
# Out:
# EASY
