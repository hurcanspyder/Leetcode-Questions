# %%
number=int(input("Enter the number"))
def watermelon(number):
    if number<=100 and number>=1:



        if number==2:
                print("NO")
        elif number%2==0:
            print("YES")
            

        else:
            print("NO")
# Out:
# YES
