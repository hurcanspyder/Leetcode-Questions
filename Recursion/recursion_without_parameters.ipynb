# %%
def print_name(count):
    
    print('abhishek')
    if count>0:
        print_name(count-1)
        count=count-1

# %%
print_name(4)
# Out:
# abhishek
# abhishek
# abhishek
# abhishek
# abhishek
