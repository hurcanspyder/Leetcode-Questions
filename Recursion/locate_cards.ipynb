# %%
def locate_cards(cards,query):
    print("LIST---->",cards)
    for i in range(0,len(cards)):
        if cards[i]==query:

             return i

        if i==len(cards):
            return -1
# cards = list(map(int, input().split()))
# query=int(input())
# locate_cards(cards,query)

# %% [markdown]
# # For the test inputs we can use Dictionary as follow

# %%
test={
    'inputs':{
        'cards':[13,11,10,7,4,3,1,0],
        'query':7
    },
    'ouput':3
}
locate_cards(**test['inputs'])==test['ouput']
# Out:
# LIST----> [13, 11, 10, 7, 4, 3, 1, 0]
# 3
# False

# %% [markdown]
# **Append more test cases in the test dictonary so that we can perform better in our code otherwise afterevery test case we may get failed with our code so be carful!!!**
