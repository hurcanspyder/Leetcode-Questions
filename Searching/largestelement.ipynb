# %%
def solve(n,squaresum):
    while n>0:
        squaresum+=(n%10)*(n%10)
        n=n//10
    return squaresum

# %%
solve(100,0)
# Out:
# 1

# %%
chr(98)
# Out:
# 'b'

# %%
ord("z")
# Out:
# 122

# %%
a="abhishek kaushal"
b=a.split(" ")

# %%
b
# Out:
# ['abhishek', 'kaushal']

# %%
c="".join(b)

# %%
c
# Out:
# 'abhishekkaushal'
