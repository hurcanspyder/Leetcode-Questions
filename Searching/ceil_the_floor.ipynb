# %%
def find(nums,target):
    n=len(nums)
    low,low1=0,0
    high,high1=n-1,n-1
    index1=[]
    lb=-1
    ub=-1
    # if target not in nums:
    #     return [-1,-1]
    # else:
    
    while low<=high:
        mid=(low+high)//2
        
        if nums[mid]>=target:

            lb=mid
            high=mid-1
            


        else:
            low=mid+1
        
    while low1<=high1:
        mid1=(low1+high1)//2
        if nums[mid1]>target:


            high1=mid1-1
            ub=mid1
        else:
            low1=mid1+1
    if target in nums:
        if target==nums[0]:
            return [-1,nums[ub]]
        if target==nums[-1]:
            return [nums[lb-1],-1]
        return [nums[lb-1],nums[ub]]
    
    
    
    else:
        if target>nums[-1]:
            return [nums[lb],-1]
        if target<nums[0]:
            return [-1,nums[ub]]
        else:
            return [nums[lb-1],nums[ub]]

# %%
find([3,4,4,4,8,9,9,10,12,12,14,15],16)
# Out:
# [15, -1]
