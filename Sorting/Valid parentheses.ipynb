# %%
def quick_sort(list1):
    for i in range()

# %%
s="{(]}"
stack=[]
stack1=[]

def isValid(s):
     
    for i in range(0,len(s)):
        if s[i]=='(' or s[i]=='{' or s[i]=='[':
            stack.append(s[i])
        if s[i]==')' or s[i]=='}' or s[i]==']':
            a=s[i]
            stack1.append(s[i])

            if s[i] == ")":
                if stack[-1]=='(':

                    stack.pop()
                    stack1.pop()
                    
                # else:
                   
                #     return False
                
                    
            if s[i]=='}':
                if stack[-1]=='{':
                    
                    stack.pop()
                    stack1.pop()
                # else:
                    
                #     return False
            if  s[i]==']':
                if stack[-1]=='[':
                    
                    stack.pop()
                    stack1.pop()
                # else:
                    
                
                #     return False
    if stack==[] and stack1==[]:
        return True
    else:
        return False

# %%
isValid(']]]]]')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 isValid(']]]]]')
#
# Cell In[104], line 33, in isValid(s)
#      29     # else:
#      30
#      31     #     return False
#      32 if  s[i]==']':
# ---> 33     if stack[-1]=='[':
#      35         stack.pop()
#      36         stack1.pop()
#
# IndexError: list index out of range
