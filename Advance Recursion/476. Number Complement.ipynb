# %%
class Solution(object):
    def findComplement(self, num):
        """
        :type num: int
        :rtype: int
        """
        def to_binary(num,list1):
            if num==1 or num==0:
                list1.append(num)
                return list1[::-1]
            list1.append(num%2)
            to_binary(num//2,list1)
            return list1[::-1]
        a=to_binary(num,[])
        list2=[]
        for i in a:
            if i==0:
                list2.append(1)
            if i==1:
                list2.append(0)
        print(a)
        sum1=0
        power=0
        for j in range(len(list2)-1,-1,-1):
            sum1+=list2[j]*2**power
            power+=1
        return sum1

# %%
3003%1337
# Out:
# 329
