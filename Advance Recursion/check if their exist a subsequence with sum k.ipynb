# %%
def backtrack(index,total,subset,target,nums,result):
    if total==target:
        # return result.append(subset.copy())
        return True
    
    elif total>target:
        return False
    if index>=len(nums):
        return False
    subset.append(nums[index])
    sum=total+nums[index]
    pick=backtrack(index+1,sum,subset,target,nums,result)
    if pick==True: return True
    e=subset.pop()
    sum=total
    not_pick=backtrack(index+1,sum,subset,target,nums,result)
    return not_pick

# %%
backtrack(0,0,[],9,[1,3,2,1],[])
# Out:
# False
