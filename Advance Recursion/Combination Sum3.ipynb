# %%
def combinationsum(index,subset,result,target,total,k):
    nums=[1,2,3,4,5,6,7,8,9]
    if total==target:
        
        if len(subset)==k:
            
            result.add(tuple(subset.copy()))
        else:
            return 
    if total>target:
        return
    if index>=len(nums):
        return 
    # if total==target:
        
    #     if len(subset)==k:
            
    #         result.add(tuple(subset.copy()))
    #     else:
    #         return 
    subset.append(nums[index])
    sum=total+nums[index]
    combinationsum(index+1,subset,result,target,sum,k)
    subset.pop()
    sum=sum-nums[index]
    combinationsum(index+1,subset,result,target,sum,k)
    return list(result)

# %%
combinationsum(0,[],set(),45,0,9)
# Out:
# [(1, 2, 3, 4, 5, 6, 7, 8, 9)]

# %%
k=3
nums=[]
for i in range(0,k):
    nums.append(i)
def combinationsum(index,subset,result,target,total,nums):
    
    if total>target:
        return
    if index>=len(nums):
        return 
    if total==target:
        
        if len(subset)==3:
            
            result.add(tuple(subset.copy()))
        else:
            return 
    subset.append(nums[index])
    sum=total+nums[index]
    combinationsum(index+1,subset,result,target,sum,nums)
    subset.pop()
    sum=sum-nums[index]
    combinationsum(index+1,subset,result,target,sum,nums)
    return list(result)

# %%
combinationsum(0,[],set(),7,0,nums)
# Out:
# []
